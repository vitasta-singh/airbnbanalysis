# %%
mongodb+srv://vitasta:<password>@cluster0.ipoknak.mongodb.net/

# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.2.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2,>=1.26.0 (from pandas)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dheeraj\airbnb\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\dheeraj\airbnb\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.1-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.1 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymongo
# Out:
# Collecting pymongoNote: you may need to restart the kernel to use updated packages.
#
#   Using cached pymongo-4.6.2-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Using cached dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Using cached pymongo-4.6.2-cp312-cp312-win_amd64.whl (472 kB)
# Using cached dnspython-2.6.1-py3-none-any.whl (307 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.6.2

# %%
pip install warnings
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement warnings (from versions: none)
# ERROR: No matching distribution found for warnings

# %%
import pymongo
import pandas as pd
pd.set_option("display.max_columns",None)
import warnings
warnings.filterwarnings("ignore")

# %%
Client= pymongo.MongoClient("mongodb+srv://vitasta:12345@cluster0.ipoknak.mongodb.net/")

db= Client["sample_airbnb"]
coll= db["listingsAndReviews"]

# %%
coll.find()

# %%
data= []

for i in coll.find({},{"_id":1, "listing_url":1, "name":1, 'property_type':1, 'room_type':1, 'bed_type':1, 'minimum_nights':1, 'maximum_nights':1, 'cancellation_policy':1, 'accommodates':1, 'bedrooms':1, 'beds':1, 'number_of_reviews':1, 'bathrooms':1, 'price':1, 'extra_people':1, 'guests_included':1, 'images.picture_url':1, 'review_scores':1,'cleaning_fee':1}):
    data.append(i)
df=pd.DataFrame(data)
df
# Out:
#            _id                            listing_url  \
# 0     10051164  https://www.airbnb.com/rooms/10051164
# 1     10066928  https://www.airbnb.com/rooms/10066928
# 2     10057826  https://www.airbnb.com/rooms/10057826
# 3     10201975  https://www.airbnb.com/rooms/10201975
# 4     10133350  https://www.airbnb.com/rooms/10133350
# ...        ...                                    ...
# 5550   9765083   https://www.airbnb.com/rooms/9765083
# 5551   9767864   https://www.airbnb.com/rooms/9767864
# 5552   9807529   https://www.airbnb.com/rooms/9807529
# 5553   9810515   https://www.airbnb.com/rooms/9810515
# 5554   9895628   https://www.airbnb.com/rooms/9895628
#
#                                        name       property_type  \
# 0        Catete's Colonial Big Hause Room B               House
# 1            3 chambres au coeur du Plateau           Apartment
# 2                         Deluxe Loft Suite           Apartment
# 3        Ipanema: moderno apê 2BR + garagem           Apartment
# 4                 2 bedroom Upper east side           Apartment
# ...                                     ...                 ...
# 5550            House in a charming village               House
# 5551                Owl's Landing- The Loft               House
# 5552  Upscale Room in The Plateau by LeQube  Serviced apartment
# 5553      Big 2bdm, Views, WIFI and carpark           Apartment
# 5554    Duplex com vista para o J. Botanico           Apartment
#
#             room_type  bed_type minimum_nights maximum_nights  \
# 0        Private room  Real Bed              2           1125
# 1     Entire home/apt  Real Bed              1           1125
# 2     Entire home/apt  Real Bed              3           1125
# 3     Entire home/apt  Real Bed              4           1125
# 4     Entire home/apt  Real Bed              2              7
# ...               ...       ...            ...            ...
# 5550     Private room  Real Bed              7           1125
# 5551     Private room  Real Bed              2             29
# 5552     Private room  Real Bed              2            224
# 5553  Entire home/apt  Real Bed              3           1125
# 5554  Entire home/apt  Real Bed              5           1125
#
#               cancellation_policy  accommodates  bedrooms  beds  \
# 0     strict_14_with_grace_period             8       1.0   8.0
# 1                        flexible             6       3.0   3.0
# 2     strict_14_with_grace_period             4       0.0   2.0
# 3     strict_14_with_grace_period             4       2.0   2.0
# 4     strict_14_with_grace_period             5       2.0   2.0
# ...                           ...           ...       ...   ...
# 5550                     flexible             2       1.0   1.0
# 5551  strict_14_with_grace_period             3       1.0   2.0
# 5552  strict_14_with_grace_period             2       1.0   1.0
# 5553  strict_14_with_grace_period             4       2.0   3.0
# 5554                     flexible             8       2.0   2.0
#
#       number_of_reviews bathrooms   price cleaning_fee extra_people  \
# 0                     1       4.0  250.00         0.00        40.00
# 1                     0       1.0  140.00          NaN         0.00
# 2                     5       1.0  205.00          NaN         0.00
# 3                    24       2.0  298.00       180.00        50.00
# 4                     9       1.0  275.00        35.00         0.00
# ...                 ...       ...     ...          ...          ...
# 5550                  0       1.0  351.00          NaN         0.00
# 5551                144       1.5   40.00          NaN        15.00
# 5552                 40       1.0   68.00        49.00         0.00
# 5553                 30       1.0  299.00       210.00         0.00
# 5554                  1       3.0  701.00       200.00         0.00
#
#      guests_included                                             images  \
# 0                  4  {'picture_url': 'https://a0.muscache.com/im/pi...
# 1                  1  {'picture_url': 'https://a0.muscache.com/im/pi...
# 2                  1  {'picture_url': 'https://a0.muscache.com/im/pi...
# 3                  2  {'picture_url': 'https://a0.muscache.com/im/pi...
# 4                  1  {'picture_url': 'https://a0.muscache.com/im/pi...
# ...              ...                                                ...
# 5550               1  {'picture_url': 'https://a0.muscache.com/im/pi...
# 5551               2  {'picture_url': 'https://a0.muscache.com/im/pi...
# 5552               2  {'picture_url': 'https://a0.muscache.com/im/pi...
# 5553               1  {'picture_url': 'https://a0.muscache.com/im/pi...
# 5554               1  {'picture_url': 'https://a0.muscache.com/im/pi...
#
#                                           review_scores
# 0     {'review_scores_accuracy': 10, 'review_scores_...
# 1                                                    {}
# 2     {'review_scores_accuracy': 9, 'review_scores_c...
# 3     {'review_scores_accuracy': 9, 'review_scores_c...
# 4     {'review_scores_accuracy': 9, 'review_scores_c...
# ...                                                 ...
# 5550                                                 {}
# 5551  {'review_scores_accuracy': 10, 'review_scores_...
# 5552  {'review_scores_accuracy': 10, 'review_scores_...
# 5553  {'review_scores_accuracy': 9, 'review_scores_c...
# 5554  {'review_scores_accuracy': 10, 'review_scores_...
#
# [5555 rows x 20 columns]

# %%
df["images"]= df["images"].apply(lambda x: x["picture_url"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df["images"]= df["images"].apply(lambda x: x["picture_url"])
#
# File c:\Users\Dheeraj\airbnb\.venv\Lib\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File c:\Users\Dheeraj\airbnb\.venv\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\Dheeraj\airbnb\.venv\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Dheeraj\airbnb\.venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\Dheeraj\airbnb\.venv\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[37], line 1, in <lambda>(x)
# ----> 1 df["images"]= df["images"].apply(lambda x: x["picture_url"])
#
# TypeError: string indices must be integers, not 'str'

# %%
df["review_scores"]= df["review_scores"].apply(lambda x: x.get("review_scores_rating",0))

# %%
df.describe().T
# Out:
#                     count       mean        std  min  25%   50%   75%    max
# accommodates       5555.0   3.505851   2.297019  1.0  2.0   3.0   4.0   16.0
# bedrooms           5550.0   1.411712   1.041942  0.0  1.0   1.0   2.0   20.0
# beds               5542.0   2.071454   1.619660  0.0  1.0   2.0   3.0   25.0
# number_of_reviews  5555.0  27.606481  49.798376  0.0  1.0   5.0  32.0  533.0
# review_scores      5555.0  68.395680  41.829834  0.0  0.0  92.0  98.0  100.0

# %%
df.isnull().sum()
# Out:
# _id                    0
# listing_url            0
# name                   0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# price                  0
# cleaning_fee           0
# extra_people           0
# guests_included        0
# images                 0
# review_scores          0
# dtype: int64

# %%
df["beds"].fillna(0,inplace= True)
df["bedrooms"].fillna(0,inplace= True)
df["bathrooms"].fillna(0,inplace= True)
df["cleaning_fee"].fillna(0,inplace= True)

# %%
df.dtypes
# Out:
# _id                     object
# listing_url             object
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights          object
# maximum_nights          object
# cancellation_policy     object
# accommodates             int64
# bedrooms               float64
# beds                   float64
# number_of_reviews        int64
# bathrooms               object
# price                   object
# cleaning_fee            object
# extra_people            object
# guests_included         object
# images                  object
# review_scores            int64
# dtype: object

# %%
df["minimum_nights"]= df["minimum_nights"].astype(int)
df["maximum_nights"]= df["maximum_nights"].astype(int)
df["bedrooms"]= df["bedrooms"].astype(int)
df["beds"]= df["beds"].astype(int)
df["bathrooms"]= df["bathrooms"].astype(str).astype(float).astype(int)
df["price"]= df["price"].astype(str).astype(float).astype(int)
df["extra_people"]= df["extra_people"].astype(str).astype(float).astype(int)
df["guests_included"]= df["guests_included"].astype(str).astype(float).astype(int)
df["cleaning_fee"]= df["cleaning_fee"].astype(str).astype(float).astype(int)

# %%
host= []
for i in coll.find({},{"_id":1, "host":1}):
    host.append(i)

# %%
df_host= pd.DataFrame(host)
df_host
# Out:
#            _id                                               host
# 0     10051164  {'host_id': '51326285', 'host_url': 'https://w...
# 1     10066928  {'host_id': '9036477', 'host_url': 'https://ww...
# 2     10057826  {'host_id': '47554473', 'host_url': 'https://w...
# 3     10201975  {'host_id': '2537111', 'host_url': 'https://ww...
# 4     10133350  {'host_id': '52004369', 'host_url': 'https://w...
# ...        ...                                                ...
# 5550   9765083  {'host_id': '50352113', 'host_url': 'https://w...
# 5551   9767864  {'host_id': '50068597', 'host_url': 'https://w...
# 5552   9807529  {'host_id': '1761366', 'host_url': 'https://ww...
# 5553   9810515  {'host_id': '33325403', 'host_url': 'https://w...
# 5554   9895628  {'host_id': '14856657', 'host_url': 'https://w...
#
# [5555 rows x 2 columns]

# %%
host_columns= {'_id':[],'host_id':[], 'host_url':[], 'host_name':[], 'host_location':[],"host_response_time":[], 'host_thumbnail_url':[], 'host_picture_url':[], 'host_neighbourhood':[], 'host_response_rate':[], 'host_is_superhost':[], 'host_has_profile_pic':[], 'host_identity_verified':[], 'host_listings_count':[], 'host_total_listings_count':[], 'host_verifications':[]}

for i in df_host["_id"]:
    host_columns["_id"].append(i)
for i in df_host["host"]:
    host_columns["host_id"].append(i["host_id"])
    host_columns["host_url"].append(i["host_url"])
    host_columns["host_name"].append(i["host_name"])
    host_columns["host_location"].append(i["host_location"])
    host_columns["host_response_time"].append(i.get("host_response_time"))
    host_columns["host_thumbnail_url"].append(i["host_thumbnail_url"])
    host_columns["host_picture_url"].append(i["host_picture_url"])
    host_columns["host_neighbourhood"].append(i["host_neighbourhood"])
    host_columns["host_response_rate"].append(i.get("host_response_rate"))
    host_columns["host_is_superhost"].append(i["host_is_superhost"])
    host_columns["host_has_profile_pic"].append(i["host_has_profile_pic"])
    host_columns["host_identity_verified"].append(i["host_identity_verified"])
    host_columns["host_listings_count"].append(i["host_listings_count"])
    host_columns["host_total_listings_count"].append(i["host_total_listings_count"])
    host_columns["host_verifications"].append(i["host_verifications"])

# %%
df_host_1= pd.DataFrame(host_columns)
df_host_1
# Out:
#            _id   host_id                                    host_url  \
# 0     10051164  51326285  https://www.airbnb.com/users/show/51326285
# 1     10066928   9036477   https://www.airbnb.com/users/show/9036477
# 2     10057826  47554473  https://www.airbnb.com/users/show/47554473
# 3     10201975   2537111   https://www.airbnb.com/users/show/2537111
# 4     10133350  52004369  https://www.airbnb.com/users/show/52004369
# ...        ...       ...                                         ...
# 5550   9765083  50352113  https://www.airbnb.com/users/show/50352113
# 5551   9767864  50068597  https://www.airbnb.com/users/show/50068597
# 5552   9807529   1761366   https://www.airbnb.com/users/show/1761366
# 5553   9810515  33325403  https://www.airbnb.com/users/show/33325403
# 5554   9895628  14856657  https://www.airbnb.com/users/show/14856657
#
#      host_name                                    host_location  \
# 0      Beatriz  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 1      Margaux                         Montreal, Quebec, Canada
# 2          Mae                                               US
# 3      Barbara  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 4      Chelsea               Sea Cliff, New York, United States
# ...        ...                                              ...
# 5550      Luiz                                               BR
# 5551      Alex                New York, New York, United States
# 5552    LeQube                         Montreal, Québec, Canada
# 5553    Andrea                       New South Wales, Australia
# 5554       Mah                      Rio, Rio de Janeiro, Brazil
#
#       host_response_time                                 host_thumbnail_url  \
# 0         within an hour  https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 1                   None  https://a0.muscache.com/im/users/9036477/profi...
# 2     within a few hours  https://a0.muscache.com/im/pictures/c680ce22-d...
# 3     within a few hours  https://a0.muscache.com/im/users/2537111/profi...
# 4                   None  https://a0.muscache.com/im/pictures/4d361f57-f...
# ...                  ...                                                ...
# 5550                None  https://a0.muscache.com/im/pictures/3c441510-e...
# 5551      within an hour  https://a0.muscache.com/im/pictures/afed82b8-1...
# 5552      within an hour  https://a0.muscache.com/im/pictures/01e4951a-f...
# 5553      within an hour  https://a0.muscache.com/im/pictures/0a464981-9...
# 5554                None  https://a0.muscache.com/im/users/14856657/prof...
#
#                                        host_picture_url  \
# 0     https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 1     https://a0.muscache.com/im/users/9036477/profi...
# 2     https://a0.muscache.com/im/pictures/c680ce22-d...
# 3     https://a0.muscache.com/im/users/2537111/profi...
# 4     https://a0.muscache.com/im/pictures/4d361f57-f...
# ...                                                 ...
# 5550  https://a0.muscache.com/im/pictures/3c441510-e...
# 5551  https://a0.muscache.com/im/pictures/afed82b8-1...
# 5552  https://a0.muscache.com/im/pictures/01e4951a-f...
# 5553  https://a0.muscache.com/im/pictures/0a464981-9...
# 5554  https://a0.muscache.com/im/users/14856657/prof...
#
#              host_neighbourhood  host_response_rate  host_is_superhost  \
# 0                        Catete                80.0              False
# 1                    Le Plateau                 NaN              False
# 2                    Greenpoint               100.0              False
# 3                  Santa Teresa                92.0               True
# 4                                               NaN              False
# ...                         ...                 ...                ...
# 5550                   Flamengo                 NaN              False
# 5551              Tompkinsville               100.0               True
# 5552                 Le Plateau               100.0              False
# 5553  Central Business District               100.0              False
# 5554            Jardim Botânico                 NaN              False
#
#       host_has_profile_pic  host_identity_verified  host_listings_count  \
# 0                     True                    True                    5
# 1                     True                   False                    2
# 2                     True                   False                   13
# 3                     True                    True                   13
# 4                     True                    True                    2
# ...                    ...                     ...                  ...
# 5550                  True                   False                    1
# 5551                  True                    True                    3
# 5552                  True                   False                   22
# 5553                  True                    True                   33
# 5554                  True                   False                    1
#
#       host_total_listings_count  \
# 0                             5
# 1                             2
# 2                            13
# 3                            13
# 4                             2
# ...                         ...
# 5550                          1
# 5551                          3
# 5552                         22
# 5553                         33
# 5554                          1
#
#                                      host_verifications
# 0     [email, phone, facebook, reviews, jumio, gover...
# 1                   [email, phone, reviews, work_email]
# 2     [email, phone, google, reviews, jumio, governm...
# 3     [email, phone, facebook, reviews, jumio, gover...
# 4     [email, phone, reviews, jumio, offline_governm...
# ...                                                 ...
# 5550                                     [email, phone]
# 5551  [email, phone, reviews, jumio, government_id, ...
# 5552  [phone, google, reviews, jumio, government_id,...
# 5553  [email, phone, manual_online, reviews, manual_...
# 5554                            [email, phone, reviews]
#
# [5555 rows x 16 columns]

# %%
df_host_1.isnull().sum()
# Out:
# _id                             0
# host_id                         0
# host_url                        0
# host_name                       0
# host_location                   0
# host_response_time           1388
# host_thumbnail_url              0
# host_picture_url                0
# host_neighbourhood              0
# host_response_rate           1388
# host_is_superhost               0
# host_has_profile_pic            0
# host_identity_verified          0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# dtype: int64

# %%
list_index= []
for index,row in df_host_1.iterrows():
    if row["host_neighbourhood"] =='':
        list_index.append(index)

# %%
len(list_index)
# Out:
# 1923

# %%
df_host_1["host_response_time"].fillna("Not Specified",inplace= True)
df_host_1["host_response_rate"].fillna("Not Specified",inplace= True)
df_host_1["host_neighbourhood"]= df_host_1["host_neighbourhood"].replace({'':"Not Specified"})

# %%
df_host_1["host_is_superhost"]= df_host_1["host_is_superhost"].map({False: "No", True: "Yes"})
df_host_1["host_has_profile_pic"]= df_host_1["host_has_profile_pic"].map({False: "No", True: "Yes"})
df_host_1["host_identity_verified"]= df_host_1["host_identity_verified"].map({False: "No", True: "Yes"})

# %%
df_host_1
# Out:
#            _id   host_id                                    host_url  \
# 0     10051164  51326285  https://www.airbnb.com/users/show/51326285
# 1     10066928   9036477   https://www.airbnb.com/users/show/9036477
# 2     10057826  47554473  https://www.airbnb.com/users/show/47554473
# 3     10201975   2537111   https://www.airbnb.com/users/show/2537111
# 4     10133350  52004369  https://www.airbnb.com/users/show/52004369
# ...        ...       ...                                         ...
# 5550   9765083  50352113  https://www.airbnb.com/users/show/50352113
# 5551   9767864  50068597  https://www.airbnb.com/users/show/50068597
# 5552   9807529   1761366   https://www.airbnb.com/users/show/1761366
# 5553   9810515  33325403  https://www.airbnb.com/users/show/33325403
# 5554   9895628  14856657  https://www.airbnb.com/users/show/14856657
#
#      host_name                                    host_location  \
# 0      Beatriz  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 1      Margaux                         Montreal, Quebec, Canada
# 2          Mae                                               US
# 3      Barbara  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 4      Chelsea               Sea Cliff, New York, United States
# ...        ...                                              ...
# 5550      Luiz                                               BR
# 5551      Alex                New York, New York, United States
# 5552    LeQube                         Montreal, Québec, Canada
# 5553    Andrea                       New South Wales, Australia
# 5554       Mah                      Rio, Rio de Janeiro, Brazil
#
#       host_response_time                                 host_thumbnail_url  \
# 0         within an hour  https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 1                   None  https://a0.muscache.com/im/users/9036477/profi...
# 2     within a few hours  https://a0.muscache.com/im/pictures/c680ce22-d...
# 3     within a few hours  https://a0.muscache.com/im/users/2537111/profi...
# 4                   None  https://a0.muscache.com/im/pictures/4d361f57-f...
# ...                  ...                                                ...
# 5550                None  https://a0.muscache.com/im/pictures/3c441510-e...
# 5551      within an hour  https://a0.muscache.com/im/pictures/afed82b8-1...
# 5552      within an hour  https://a0.muscache.com/im/pictures/01e4951a-f...
# 5553      within an hour  https://a0.muscache.com/im/pictures/0a464981-9...
# 5554                None  https://a0.muscache.com/im/users/14856657/prof...
#
#                                        host_picture_url  \
# 0     https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 1     https://a0.muscache.com/im/users/9036477/profi...
# 2     https://a0.muscache.com/im/pictures/c680ce22-d...
# 3     https://a0.muscache.com/im/users/2537111/profi...
# 4     https://a0.muscache.com/im/pictures/4d361f57-f...
# ...                                                 ...
# 5550  https://a0.muscache.com/im/pictures/3c441510-e...
# 5551  https://a0.muscache.com/im/pictures/afed82b8-1...
# 5552  https://a0.muscache.com/im/pictures/01e4951a-f...
# 5553  https://a0.muscache.com/im/pictures/0a464981-9...
# 5554  https://a0.muscache.com/im/users/14856657/prof...
#
#              host_neighbourhood  host_response_rate host_is_superhost  \
# 0                        Catete                80.0                No
# 1                    Le Plateau                 NaN                No
# 2                    Greenpoint               100.0                No
# 3                  Santa Teresa                92.0               Yes
# 4                                               NaN                No
# ...                         ...                 ...               ...
# 5550                   Flamengo                 NaN                No
# 5551              Tompkinsville               100.0               Yes
# 5552                 Le Plateau               100.0                No
# 5553  Central Business District               100.0                No
# 5554            Jardim Botânico                 NaN                No
#
#      host_has_profile_pic host_identity_verified  host_listings_count  \
# 0                     Yes                    Yes                    5
# 1                     Yes                     No                    2
# 2                     Yes                     No                   13
# 3                     Yes                    Yes                   13
# 4                     Yes                    Yes                    2
# ...                   ...                    ...                  ...
# 5550                  Yes                     No                    1
# 5551                  Yes                    Yes                    3
# 5552                  Yes                     No                   22
# 5553                  Yes                    Yes                   33
# 5554                  Yes                     No                    1
#
#       host_total_listings_count  \
# 0                             5
# 1                             2
# 2                            13
# 3                            13
# 4                             2
# ...                         ...
# 5550                          1
# 5551                          3
# 5552                         22
# 5553                         33
# 5554                          1
#
#                                      host_verifications
# 0     [email, phone, facebook, reviews, jumio, gover...
# 1                   [email, phone, reviews, work_email]
# 2     [email, phone, google, reviews, jumio, governm...
# 3     [email, phone, facebook, reviews, jumio, gover...
# 4     [email, phone, reviews, jumio, offline_governm...
# ...                                                 ...
# 5550                                     [email, phone]
# 5551  [email, phone, reviews, jumio, government_id, ...
# 5552  [phone, google, reviews, jumio, government_id,...
# 5553  [email, phone, manual_online, reviews, manual_...
# 5554                            [email, phone, reviews]
#
# [5555 rows x 16 columns]

# %%
availability= []
for i in coll.find({}, {"_id":1, "availability":1}):
    availability.append(i)
availability 
df_available=pd.DataFrame(availability)

# %%
available_columns= {'_id':[], 'availability_30':[], 'availability_60':[], 'availability_90':[], 'availability_365':[]}

for i in df_available["_id"]:
    available_columns["_id"].append(i)
for i in df_available["availability"]:
    available_columns["availability_30"].append(i["availability_30"])
    available_columns["availability_60"].append(i["availability_60"])
    available_columns["availability_90"].append(i["availability_90"])
    available_columns["availability_365"].append(i["availability_365"])
df_available_1= pd.DataFrame(available_columns)

# %%
df_available_1
# Out:
#            _id  availability_30  availability_60  availability_90  \
# 0     10051164               10               10               21
# 1     10066928                0                0                0
# 2     10057826               30               31               31
# 3     10201975               24               54               84
# 4     10133350                0                0                0
# ...        ...              ...              ...              ...
# 5550   9765083                0                0                0
# 5551   9767864               30               53               73
# 5552   9807529               15               30               31
# 5553   9810515                8               28               58
# 5554   9895628                0                0                0
#
#       availability_365
# 0                  296
# 1                    0
# 2                  243
# 3                  174
# 4                    0
# ...                ...
# 5550                 0
# 5551               343
# 5552               100
# 5553               135
# 5554                 0
#
# [5555 rows x 5 columns]

# %%
amenities= []
for i in coll.find({},{"_id":1, "amenities":1}):
    amenities.append(i)
df_amenities= pd.DataFrame(amenities)

def sort_amenities(x):
    a= x
    a.sort()
    return a
df_amenities["amenities"]= df_amenities["amenities"].apply(lambda x: sort_amenities(x))
df_amenities
# Out:
#            _id                                          amenities
# 0     10051164  [Air conditioning, Cable TV, Essentials, Famil...
# 1     10066928  [Dryer, Essentials, Family/kid friendly, Hair ...
# 2     10057826  [24-hour check-in, Air conditioning, Cable TV,...
# 3     10201975  [24-hour check-in, Air conditioning, Buzzer/wi...
# 4     10133350  [Air conditioning, Buzzer/wireless intercom, C...
# ...        ...                                                ...
# 5550   9765083  [Essentials, Hangers, Internet, Kitchen, Lapto...
# 5551   9767864  [Air conditioning, BBQ grill, Bathtub, Bed lin...
# 5552   9807529  [Accessible-height bed, Accessible-height toil...
# 5553   9810515  [24-hour check-in, Air conditioning, Bathtub, ...
# 5554   9895628  [Air conditioning, Buzzer/wireless intercom, C...
#
# [5555 rows x 2 columns]

# %%
address= []
for i in coll.find({}, {"_id":1, "address":1}):
    address.append(i)
df_address= pd.DataFrame(address)
address_columns= {'_id':[], 'street':[], 'suburb':[], 'government_area':[], 'market':[], 'country':[],
                   'country_code':[], 'location_type':[], "longitude":[], "latitude":[],
                    "is_location_exact":[]}

for i in df_address["_id"]:
    address_columns["_id"].append(i)

for i in df_address["address"]:
    address_columns["street"].append(i["street"])
    address_columns["suburb"].append(i["suburb"])
    address_columns["government_area"].append(i["government_area"])
    address_columns["market"].append(i["market"])
    address_columns["country"].append(i["country"])
    address_columns["country_code"].append(i["country_code"])
    address_columns["location_type"].append(i["location"]["type"])
    address_columns["longitude"].append(i["location"]["coordinates"][0])
    address_columns["latitude"].append(i["location"]["coordinates"][1])
    address_columns["is_location_exact"].append(i["location"]["is_location_exact"])
df_address_1= pd.DataFrame(address_columns)
df_address_1
# Out:
#            _id                                  street                 suburb  \
# 0     10051164  Rio de Janeiro, Rio de Janeiro, Brazil                 Catete
# 1     10066928                Montréal, Québec, Canada  Le Plateau-Mont-Royal
# 2     10057826             Brooklyn, NY, United States             Greenpoint
# 3     10201975  Rio de Janeiro, Rio de Janeiro, Brazil
# 4     10133350             New York, NY, United States        Upper East Side
# ...        ...                                     ...                    ...
# 5550   9765083  Rio de Janeiro, Rio de Janeiro, Brazil               Flamengo
# 5551   9767864        Staten Island, NY, United States          Staten Island
# 5552   9807529                Montréal, Québec, Canada             Le Plateau
# 5553   9810515           Woolloomooloo, NSW, Australia          Woolloomooloo
# 5554   9895628  Rio de Janeiro, Rio de Janeiro, Brazil        Jardim Botânico
#
#             government_area          market        country country_code  \
# 0                    Catete  Rio De Janeiro         Brazil           BR
# 1     Le Plateau-Mont-Royal        Montreal         Canada           CA
# 2                Greenpoint        New York  United States           US
# 3                   Ipanema  Rio De Janeiro         Brazil           BR
# 4           Upper East Side        New York  United States           US
# ...                     ...             ...            ...          ...
# 5550               Flamengo  Rio De Janeiro         Brazil           BR
# 5551          Tompkinsville        New York  United States           US
# 5552  Le Plateau-Mont-Royal        Montreal         Canada           CA
# 5553                 Sydney          Sydney      Australia           AU
# 5554        Jardim Botânico  Rio De Janeiro         Brazil           BR
#
#      location_type   longitude   latitude  is_location_exact
# 0            Point  -43.180157 -22.926382               True
# 1            Point  -73.573830  45.522330               True
# 2            Point  -73.944720  40.727780               True
# 3            Point  -43.199846 -22.980052              False
# 4            Point  -73.958540  40.766400              False
# ...            ...         ...        ...                ...
# 5550         Point  -43.175503 -22.929367               True
# 5551         Point  -74.078680  40.636610               True
# 5552         Point  -73.574530  45.523240               True
# 5553         Point  151.220670 -33.870070               True
# 5554         Point  -43.220452 -22.963607               True
#
# [5555 rows x 11 columns]

# %%
id_e=[]
stre_e=[]
suburb_e=[]
gov_e=[]
mark_e=[]
cntry_e=[]
cntry_co_e=[]
loc_ty_e=[]
long_e=[]
lat_e=[]
is_loc_tr_e=[]
for index,row in df_address_1.iterrows():
    if row["_id"] == '':
        id_e.append(index)

    if row["street"] == '':
        stre_e.append(index)
        
    if row["suburb"] == '':
        suburb_e.append(index)

    if row["government_area"] == '':
        gov_e.append(index)

    if row["market"] == '':
        mark_e.append(index)

    if row["country"] == '':
        cntry_e.append(index)
    
    if row["country_code"] == '':
        cntry_co_e.append(index)

    if row["location_type"] == '':
        loc_ty_e.append(index) 

    if row["longitude"] == '':
        long_e.append(index)

    if row["latitude"] == '':
        lat_e.append(index)

    if row["is_location_exact"] == '':
        is_loc_tr_e.append(index)   
empty_columns=[id_e,stre_e,suburb_e,gov_e,mark_e,cntry_e,cntry_co_e,loc_ty_e,long_e,lat_e,is_loc_tr_e]
for i in empty_columns:
    print(len(i))
# Out:
# 0
# 0
# 887
# 0
# 6
# 0
# 0
# 0
# 0
# 0
# 0

# %%
df_address_1["suburb"]= df_address_1["suburb"].replace({'':"Not Specified"})
df_address_1["market"]= df_address_1["market"].replace({'':"Not Specified"})

df_address_1["is_location_exact"]= df_address_1["is_location_exact"].map({False:"No", True:"Yes"})

# %%
df_address_1
# Out:
#            _id                                  street                 suburb  \
# 0     10051164  Rio de Janeiro, Rio de Janeiro, Brazil                 Catete
# 1     10066928                Montréal, Québec, Canada  Le Plateau-Mont-Royal
# 2     10057826             Brooklyn, NY, United States             Greenpoint
# 3     10201975  Rio de Janeiro, Rio de Janeiro, Brazil          Not Specified
# 4     10133350             New York, NY, United States        Upper East Side
# ...        ...                                     ...                    ...
# 5550   9765083  Rio de Janeiro, Rio de Janeiro, Brazil               Flamengo
# 5551   9767864        Staten Island, NY, United States          Staten Island
# 5552   9807529                Montréal, Québec, Canada             Le Plateau
# 5553   9810515           Woolloomooloo, NSW, Australia          Woolloomooloo
# 5554   9895628  Rio de Janeiro, Rio de Janeiro, Brazil        Jardim Botânico
#
#             government_area          market        country country_code  \
# 0                    Catete  Rio De Janeiro         Brazil           BR
# 1     Le Plateau-Mont-Royal        Montreal         Canada           CA
# 2                Greenpoint        New York  United States           US
# 3                   Ipanema  Rio De Janeiro         Brazil           BR
# 4           Upper East Side        New York  United States           US
# ...                     ...             ...            ...          ...
# 5550               Flamengo  Rio De Janeiro         Brazil           BR
# 5551          Tompkinsville        New York  United States           US
# 5552  Le Plateau-Mont-Royal        Montreal         Canada           CA
# 5553                 Sydney          Sydney      Australia           AU
# 5554        Jardim Botânico  Rio De Janeiro         Brazil           BR
#
#      location_type   longitude   latitude is_location_exact
# 0            Point  -43.180157 -22.926382               Yes
# 1            Point  -73.573830  45.522330               Yes
# 2            Point  -73.944720  40.727780               Yes
# 3            Point  -43.199846 -22.980052                No
# 4            Point  -73.958540  40.766400                No
# ...            ...         ...        ...               ...
# 5550         Point  -43.175503 -22.929367               Yes
# 5551         Point  -74.078680  40.636610               Yes
# 5552         Point  -73.574530  45.523240               Yes
# 5553         Point  151.220670 -33.870070               Yes
# 5554         Point  -43.220452 -22.963607               Yes
#
# [5555 rows x 11 columns]

# %%
df= pd.merge(df, df_host_1, on="_id")
df= pd.merge(df, df_address_1, on="_id")
df= pd.merge(df, df_available_1, on="_id")
df= pd.merge(df, df_amenities, on="_id")

# %%
df.to_csv("Airbnb.csv", index= False)

# %%
df= pd.read_csv("C:/Users/Dheeraj/airbnb/Airbnb.csv")
df
# Out:
#            _id                            listing_url  \
# 0     10051164  https://www.airbnb.com/rooms/10051164
# 1     10066928  https://www.airbnb.com/rooms/10066928
# 2     10057826  https://www.airbnb.com/rooms/10057826
# 3     10201975  https://www.airbnb.com/rooms/10201975
# 4     10133350  https://www.airbnb.com/rooms/10133350
# ...        ...                                    ...
# 5550   9765083   https://www.airbnb.com/rooms/9765083
# 5551   9767864   https://www.airbnb.com/rooms/9767864
# 5552   9807529   https://www.airbnb.com/rooms/9807529
# 5553   9810515   https://www.airbnb.com/rooms/9810515
# 5554   9895628   https://www.airbnb.com/rooms/9895628
#
#                                        name       property_type  \
# 0        Catete's Colonial Big Hause Room B               House
# 1            3 chambres au coeur du Plateau           Apartment
# 2                         Deluxe Loft Suite           Apartment
# 3        Ipanema: moderno apê 2BR + garagem           Apartment
# 4                 2 bedroom Upper east side           Apartment
# ...                                     ...                 ...
# 5550            House in a charming village               House
# 5551                Owl's Landing- The Loft               House
# 5552  Upscale Room in The Plateau by LeQube  Serviced apartment
# 5553      Big 2bdm, Views, WIFI and carpark           Apartment
# 5554    Duplex com vista para o J. Botanico           Apartment
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# 0        Private room  Real Bed               2            1125
# 1     Entire home/apt  Real Bed               1            1125
# 2     Entire home/apt  Real Bed               3            1125
# 3     Entire home/apt  Real Bed               4            1125
# 4     Entire home/apt  Real Bed               2               7
# ...               ...       ...             ...             ...
# 5550     Private room  Real Bed               7            1125
# 5551     Private room  Real Bed               2              29
# 5552     Private room  Real Bed               2             224
# 5553  Entire home/apt  Real Bed               3            1125
# 5554  Entire home/apt  Real Bed               5            1125
#
#               cancellation_policy  accommodates  bedrooms  beds  \
# 0     strict_14_with_grace_period             8         1     8
# 1                        flexible             6         3     3
# 2     strict_14_with_grace_period             4         0     2
# 3     strict_14_with_grace_period             4         2     2
# 4     strict_14_with_grace_period             5         2     2
# ...                           ...           ...       ...   ...
# 5550                     flexible             2         1     1
# 5551  strict_14_with_grace_period             3         1     2
# 5552  strict_14_with_grace_period             2         1     1
# 5553  strict_14_with_grace_period             4         2     3
# 5554                     flexible             8         2     2
#
#       number_of_reviews  bathrooms  price  cleaning_fee  extra_people  \
# 0                     1          4    250             0            40
# 1                     0          1    140             0             0
# 2                     5          1    205             0             0
# 3                    24          2    298           180            50
# 4                     9          1    275            35             0
# ...                 ...        ...    ...           ...           ...
# 5550                  0          1    351             0             0
# 5551                144          1     40             0            15
# 5552                 40          1     68            49             0
# 5553                 30          1    299           210             0
# 5554                  1          3    701           200             0
#
#       guests_included                                             images  \
# 0                   4  https://a0.muscache.com/im/pictures/b2119f25-4...
# 1                   1  https://a0.muscache.com/im/pictures/f208bdd7-b...
# 2                   1  https://a0.muscache.com/im/pictures/40ace1e3-4...
# 3                   2  https://a0.muscache.com/im/pictures/d2ccb4bd-1...
# 4                   1  https://a0.muscache.com/im/pictures/d9886a79-0...
# ...               ...                                                ...
# 5550                1  https://a0.muscache.com/im/pictures/a51e6ddb-2...
# 5551                2  https://a0.muscache.com/im/pictures/3d111a9b-e...
# 5552                2  https://a0.muscache.com/im/pictures/e8bd43ea-2...
# 5553                1  https://a0.muscache.com/im/pictures/0aa1c7ea-9...
# 5554                1  https://a0.muscache.com/im/pictures/55e7014a-6...
#
#       review_scores  host_id_x                                  host_url_x  \
# 0                80   51326285  https://www.airbnb.com/users/show/51326285
# 1                 0    9036477   https://www.airbnb.com/users/show/9036477
# 2                88   47554473  https://www.airbnb.com/users/show/47554473
# 3                92    2537111   https://www.airbnb.com/users/show/2537111
# 4                90   52004369  https://www.airbnb.com/users/show/52004369
# ...             ...        ...                                         ...
# 5550              0   50352113  https://www.airbnb.com/users/show/50352113
# 5551             96   50068597  https://www.airbnb.com/users/show/50068597
# 5552             97    1761366   https://www.airbnb.com/users/show/1761366
# 5553             93   33325403  https://www.airbnb.com/users/show/33325403
# 5554            100   14856657  https://www.airbnb.com/users/show/14856657
#
#      host_name_x                                  host_location_x  \
# 0        Beatriz  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 1        Margaux                         Montreal, Quebec, Canada
# 2            Mae                                               US
# 3        Barbara  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 4        Chelsea               Sea Cliff, New York, United States
# ...          ...                                              ...
# 5550        Luiz                                               BR
# 5551        Alex                New York, New York, United States
# 5552      LeQube                         Montreal, Québec, Canada
# 5553      Andrea                       New South Wales, Australia
# 5554         Mah                      Rio, Rio de Janeiro, Brazil
#
#      host_response_time_x                               host_thumbnail_url_x  \
# 0          within an hour  https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 1                     NaN  https://a0.muscache.com/im/users/9036477/profi...
# 2      within a few hours  https://a0.muscache.com/im/pictures/c680ce22-d...
# 3      within a few hours  https://a0.muscache.com/im/users/2537111/profi...
# 4                     NaN  https://a0.muscache.com/im/pictures/4d361f57-f...
# ...                   ...                                                ...
# 5550                  NaN  https://a0.muscache.com/im/pictures/3c441510-e...
# 5551       within an hour  https://a0.muscache.com/im/pictures/afed82b8-1...
# 5552       within an hour  https://a0.muscache.com/im/pictures/01e4951a-f...
# 5553       within an hour  https://a0.muscache.com/im/pictures/0a464981-9...
# 5554                  NaN  https://a0.muscache.com/im/users/14856657/prof...
#
#                                      host_picture_url_x  \
# 0     https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 1     https://a0.muscache.com/im/users/9036477/profi...
# 2     https://a0.muscache.com/im/pictures/c680ce22-d...
# 3     https://a0.muscache.com/im/users/2537111/profi...
# 4     https://a0.muscache.com/im/pictures/4d361f57-f...
# ...                                                 ...
# 5550  https://a0.muscache.com/im/pictures/3c441510-e...
# 5551  https://a0.muscache.com/im/pictures/afed82b8-1...
# 5552  https://a0.muscache.com/im/pictures/01e4951a-f...
# 5553  https://a0.muscache.com/im/pictures/0a464981-9...
# 5554  https://a0.muscache.com/im/users/14856657/prof...
#
#            host_neighbourhood_x  host_response_rate_x host_is_superhost_x  \
# 0                        Catete                  80.0                  No
# 1                    Le Plateau                   NaN                  No
# 2                    Greenpoint                 100.0                  No
# 3                  Santa Teresa                  92.0                 Yes
# 4                           NaN                   NaN                  No
# ...                         ...                   ...                 ...
# 5550                   Flamengo                   NaN                  No
# 5551              Tompkinsville                 100.0                 Yes
# 5552                 Le Plateau                 100.0                  No
# 5553  Central Business District                 100.0                  No
# 5554            Jardim Botânico                   NaN                  No
#
#      host_has_profile_pic_x host_identity_verified_x  host_listings_count_x  \
# 0                       Yes                      Yes                      5
# 1                       Yes                       No                      2
# 2                       Yes                       No                     13
# 3                       Yes                      Yes                     13
# 4                       Yes                      Yes                      2
# ...                     ...                      ...                    ...
# 5550                    Yes                       No                      1
# 5551                    Yes                      Yes                      3
# 5552                    Yes                       No                     22
# 5553                    Yes                      Yes                     33
# 5554                    Yes                       No                      1
#
#       host_total_listings_count_x  \
# 0                               5
# 1                               2
# 2                              13
# 3                              13
# 4                               2
# ...                           ...
# 5550                            1
# 5551                            3
# 5552                           22
# 5553                           33
# 5554                            1
#
#                                    host_verifications_x  host_id_y  \
# 0     ['email', 'phone', 'facebook', 'reviews', 'jum...   51326285
# 1           ['email', 'phone', 'reviews', 'work_email']    9036477
# 2     ['email', 'phone', 'google', 'reviews', 'jumio...   47554473
# 3     ['email', 'phone', 'facebook', 'reviews', 'jum...    2537111
# 4     ['email', 'phone', 'reviews', 'jumio', 'offlin...   52004369
# ...                                                 ...        ...
# 5550                                 ['email', 'phone']   50352113
# 5551  ['email', 'phone', 'reviews', 'jumio', 'govern...   50068597
# 5552  ['phone', 'google', 'reviews', 'jumio', 'gover...    1761366
# 5553  ['email', 'phone', 'manual_online', 'reviews',...   33325403
# 5554                      ['email', 'phone', 'reviews']   14856657
#
#                                       host_url_y host_name_y  \
# 0     https://www.airbnb.com/users/show/51326285     Beatriz
# 1      https://www.airbnb.com/users/show/9036477     Margaux
# 2     https://www.airbnb.com/users/show/47554473         Mae
# 3      https://www.airbnb.com/users/show/2537111     Barbara
# 4     https://www.airbnb.com/users/show/52004369     Chelsea
# ...                                          ...         ...
# 5550  https://www.airbnb.com/users/show/50352113        Luiz
# 5551  https://www.airbnb.com/users/show/50068597        Alex
# 5552   https://www.airbnb.com/users/show/1761366      LeQube
# 5553  https://www.airbnb.com/users/show/33325403      Andrea
# 5554  https://www.airbnb.com/users/show/14856657         Mah
#
#                                       host_location_y host_response_time_y  \
# 0     Rio de Janeiro, State of Rio de Janeiro, Brazil       within an hour
# 1                            Montreal, Quebec, Canada                  NaN
# 2                                                  US   within a few hours
# 3     Rio de Janeiro, State of Rio de Janeiro, Brazil   within a few hours
# 4                  Sea Cliff, New York, United States                  NaN
# ...                                               ...                  ...
# 5550                                               BR                  NaN
# 5551                New York, New York, United States       within an hour
# 5552                         Montreal, Québec, Canada       within an hour
# 5553                       New South Wales, Australia       within an hour
# 5554                      Rio, Rio de Janeiro, Brazil                  NaN
#
#                                    host_thumbnail_url_y  \
# 0     https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 1     https://a0.muscache.com/im/users/9036477/profi...
# 2     https://a0.muscache.com/im/pictures/c680ce22-d...
# 3     https://a0.muscache.com/im/users/2537111/profi...
# 4     https://a0.muscache.com/im/pictures/4d361f57-f...
# ...                                                 ...
# 5550  https://a0.muscache.com/im/pictures/3c441510-e...
# 5551  https://a0.muscache.com/im/pictures/afed82b8-1...
# 5552  https://a0.muscache.com/im/pictures/01e4951a-f...
# 5553  https://a0.muscache.com/im/pictures/0a464981-9...
# 5554  https://a0.muscache.com/im/users/14856657/prof...
#
#                                      host_picture_url_y  \
# 0     https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 1     https://a0.muscache.com/im/users/9036477/profi...
# 2     https://a0.muscache.com/im/pictures/c680ce22-d...
# 3     https://a0.muscache.com/im/users/2537111/profi...
# 4     https://a0.muscache.com/im/pictures/4d361f57-f...
# ...                                                 ...
# 5550  https://a0.muscache.com/im/pictures/3c441510-e...
# 5551  https://a0.muscache.com/im/pictures/afed82b8-1...
# 5552  https://a0.muscache.com/im/pictures/01e4951a-f...
# 5553  https://a0.muscache.com/im/pictures/0a464981-9...
# 5554  https://a0.muscache.com/im/users/14856657/prof...
#
#            host_neighbourhood_y  host_response_rate_y host_is_superhost_y  \
# 0                        Catete                  80.0                  No
# 1                    Le Plateau                   NaN                  No
# 2                    Greenpoint                 100.0                  No
# 3                  Santa Teresa                  92.0                 Yes
# 4                           NaN                   NaN                  No
# ...                         ...                   ...                 ...
# 5550                   Flamengo                   NaN                  No
# 5551              Tompkinsville                 100.0                 Yes
# 5552                 Le Plateau                 100.0                  No
# 5553  Central Business District                 100.0                  No
# 5554            Jardim Botânico                   NaN                  No
#
#      host_has_profile_pic_y host_identity_verified_y  host_listings_count_y  \
# 0                       Yes                      Yes                      5
# 1                       Yes                       No                      2
# 2                       Yes                       No                     13
# 3                       Yes                      Yes                     13
# 4                       Yes                      Yes                      2
# ...                     ...                      ...                    ...
# 5550                    Yes                       No                      1
# 5551                    Yes                      Yes                      3
# 5552                    Yes                       No                     22
# 5553                    Yes                      Yes                     33
# 5554                    Yes                       No                      1
#
#       host_total_listings_count_y  \
# 0                               5
# 1                               2
# 2                              13
# 3                              13
# 4                               2
# ...                           ...
# 5550                            1
# 5551                            3
# 5552                           22
# 5553                           33
# 5554                            1
#
#                                    host_verifications_y  \
# 0     ['email', 'phone', 'facebook', 'reviews', 'jum...
# 1           ['email', 'phone', 'reviews', 'work_email']
# 2     ['email', 'phone', 'google', 'reviews', 'jumio...
# 3     ['email', 'phone', 'facebook', 'reviews', 'jum...
# 4     ['email', 'phone', 'reviews', 'jumio', 'offlin...
# ...                                                 ...
# 5550                                 ['email', 'phone']
# 5551  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 5552  ['phone', 'google', 'reviews', 'jumio', 'gover...
# 5553  ['email', 'phone', 'manual_online', 'reviews',...
# 5554                      ['email', 'phone', 'reviews']
#
#                                       street                 suburb  \
# 0     Rio de Janeiro, Rio de Janeiro, Brazil                 Catete
# 1                   Montréal, Québec, Canada  Le Plateau-Mont-Royal
# 2                Brooklyn, NY, United States             Greenpoint
# 3     Rio de Janeiro, Rio de Janeiro, Brazil          Not Specified
# 4                New York, NY, United States        Upper East Side
# ...                                      ...                    ...
# 5550  Rio de Janeiro, Rio de Janeiro, Brazil               Flamengo
# 5551        Staten Island, NY, United States          Staten Island
# 5552                Montréal, Québec, Canada             Le Plateau
# 5553           Woolloomooloo, NSW, Australia          Woolloomooloo
# 5554  Rio de Janeiro, Rio de Janeiro, Brazil        Jardim Botânico
#
#             government_area          market        country country_code  \
# 0                    Catete  Rio De Janeiro         Brazil           BR
# 1     Le Plateau-Mont-Royal        Montreal         Canada           CA
# 2                Greenpoint        New York  United States           US
# 3                   Ipanema  Rio De Janeiro         Brazil           BR
# 4           Upper East Side        New York  United States           US
# ...                     ...             ...            ...          ...
# 5550               Flamengo  Rio De Janeiro         Brazil           BR
# 5551          Tompkinsville        New York  United States           US
# 5552  Le Plateau-Mont-Royal        Montreal         Canada           CA
# 5553                 Sydney          Sydney      Australia           AU
# 5554        Jardim Botânico  Rio De Janeiro         Brazil           BR
#
#      location_type   longitude   latitude is_location_exact  availability_30  \
# 0            Point  -43.180157 -22.926382               Yes               10
# 1            Point  -73.573830  45.522330               Yes                0
# 2            Point  -73.944720  40.727780               Yes               30
# 3            Point  -43.199846 -22.980052                No               24
# 4            Point  -73.958540  40.766400                No                0
# ...            ...         ...        ...               ...              ...
# 5550         Point  -43.175503 -22.929367               Yes                0
# 5551         Point  -74.078680  40.636610               Yes               30
# 5552         Point  -73.574530  45.523240               Yes               15
# 5553         Point  151.220670 -33.870070               Yes                8
# 5554         Point  -43.220452 -22.963607               Yes                0
#
#       availability_60  availability_90  availability_365  \
# 0                  10               21               296
# 1                   0                0                 0
# 2                  31               31               243
# 3                  54               84               174
# 4                   0                0                 0
# ...               ...              ...               ...
# 5550                0                0                 0
# 5551               53               73               343
# 5552               30               31               100
# 5553               28               58               135
# 5554                0                0                 0
#
#                                               amenities
# 0     ['Air conditioning', 'Cable TV', 'Essentials',...
# 1     ['Dryer', 'Essentials', 'Family/kid friendly',...
# 2     ['24-hour check-in', 'Air conditioning', 'Cabl...
# 3     ['24-hour check-in', 'Air conditioning', 'Buzz...
# 4     ['Air conditioning', 'Buzzer/wireless intercom...
# ...                                                 ...
# 5550  ['Essentials', 'Hangers', 'Internet', 'Kitchen...
# 5551  ['Air conditioning', 'BBQ grill', 'Bathtub', '...
# 5552  ['Accessible-height bed', 'Accessible-height t...
# 5553  ['24-hour check-in', 'Air conditioning', 'Bath...
# 5554  ['Air conditioning', 'Buzzer/wireless intercom...
#
# [5555 rows x 65 columns]
